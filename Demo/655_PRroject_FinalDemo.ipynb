# %%
import os

os.makedirs("examples", exist_ok=True)
os.makedirs("models", exist_ok=True)

# %%
import os
# Check for the images at the expected absolute paths in Colab
path1 = "/content/examples/tomato_overripe_kaggle2_0733.jpg"
path2 = "/content/examples/tomato_unripe_kaggle2_0695.jpg"

print(f"✅ sample1.jpg uploaded: {os.path.exists(path1)}")
print(f"✅ sample2.jpg uploaded: {os.path.exists(path2)}")
# Out:
# ✅ sample1.jpg uploaded: True
# ✅ sample2.jpg uploaded: True

# %%
# !pip install gradio

# %%
# !python app.py
# Out:
# 2026-04-19 02:05:46.431594: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-19 02:05:46.437778: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-19 02:05:46.467080: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776564346.518635   39474 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776564346.533986   39474 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
